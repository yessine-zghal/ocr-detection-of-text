# %%
import pytesseract #we neeed for detection

# %%
import cv2 #we need for vusialize image

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # for configuration

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
img = cv2.imread('test3.png')

# %%
plt.imshow(img)

# %%
img2char = pytesseract.image_to_string(img) #convert image to string

# %%
print(img2char)#print all string in the image
# Out:
# joy of data

# %%
imgboxes = pytesseract.image_to_boxes(img)#convert and find each caractere the boxes

# %%
print(imgboxes)
# Out:
# j 189 105 228 202 0
# o 246 126 296 181 0
# y 303 105 355 180 0
# o 423 126 473 181 0
# f 481 127 532 202 0
# d 601 126 646 202 0
# a 661 126 705 181 0
# t 716 126 764 197 0
# a 779 126 823 181 0

# %%
imgh,imgw,_ = img.shape

# %%
for boxes in imgboxes.splitlines():#make bonding boxes 
    boxes = boxes.split(" ")
    x,y,w,h = int(boxes[1]),int(boxes[2]),int(boxes[3]),int(boxes[4])
    cv2.rectangle(img,(x,imgh-y),(w,imgh-h),(0,0,255),3 )
    cv2.putText(img,boxes[0],(x,imgh-y+25),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),3)

# %%
plt.imshow(img)#by default cv2 is BGR

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font_scale = 1.5
